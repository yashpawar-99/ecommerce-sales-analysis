# %%
import pandas as pd
df = pd.read_csv("../data/train.csv")

# %%
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
#Number of rows
no_row = df.shape[0]
print(f"Number Of rows Is : {no_row}\n")

#Number of columns
no_col = df.shape[1]
print(f"Number of Columns : {no_col}\n")

#All column names
print(df.columns)

#Data types of every column
df.info()

#Number of missing values in every column
missing_value = df.isnull().sum()
print(f"\n Number of missing values in every column : \n{missing_value}\n")

#Number of duplicate rows
duplicates = df.duplicated().sum()
print(f"\n Number of duplicate rows : {duplicates}")
# Out:
# Number Of rows Is : 9800
#
# Number of Columns : 18
#
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
# ...

# %%
#Order Date → datetime

df["Order Date"] = pd.to_datetime(df["Order Date"],dayfirst=True)

#Ship Date  → datetime
df["Ship Date"] = pd.to_datetime(df["Ship Date"],dayfirst=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   datetime64[ns]
#  3   Ship Date      9800 non-null   datetime64[ns]
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
df.shape
# Out:
# (9800, 18)

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9800, step=1)

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code             float64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# dtype: object

# %%
#chaking a missing postal code 
empty_psc = df.loc[df["Postal Code"].isnull(),["City","State","Postal Code"]]
empty_psc
# Out:
#             City    State  Postal Code
# 2234  Burlington  Vermont          NaN
# 5274  Burlington  Vermont          NaN
# 8798  Burlington  Vermont          NaN
# 9146  Burlington  Vermont          NaN
# 9147  Burlington  Vermont          NaN
# 9148  Burlington  Vermont          NaN
# 9386  Burlington  Vermont          NaN
# 9387  Burlington  Vermont          NaN
# 9388  Burlington  Vermont          NaN
# 9389  Burlington  Vermont          NaN
# 9741  Burlington  Vermont          NaN

# %%
df.loc[(df["City"]=='Burlington') & (df["State"]=='Vermont'),["City","State","Postal Code"]]
# Out:
#             City    State  Postal Code
# 2234  Burlington  Vermont          NaN
# 5274  Burlington  Vermont          NaN
# 8798  Burlington  Vermont          NaN
# 9146  Burlington  Vermont          NaN
# 9147  Burlington  Vermont          NaN
# 9148  Burlington  Vermont          NaN
# 9386  Burlington  Vermont          NaN
# 9387  Burlington  Vermont          NaN
# 9388  Burlington  Vermont          NaN
# 9389  Burlington  Vermont          NaN
# 9741  Burlington  Vermont          NaN

# %%
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code             float64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# dtype: object

# %%
df["Postal Code"] = df["Postal Code"].astype("Int64")

# %%
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               Int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# dtype: object

# %%
df["Sales"].min()
# Out:
# 0.444

# %%
df["Sales"].max()
# Out:
# 22638.48

# %%
df["Sales"].mean()
# Out:
# np.float64(230.76905945918367)

# %%
df["Sales"].median()
# Out:
# 54.489999999999995

# %%
#How many orders have Sales greater than 1,000?
df[df["Sales"]>1000].shape
# Out:
# (462, 18)

# %%
#10 rows with the highest Sales values
highest_sales = df.sort_values("Sales",ascending = False)
high = highest_sales[0:10]
high
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2697    2698  CA-2015-145317 2015-03-18 2015-03-23  Standard Class
# 6826    6827  CA-2017-118689 2017-10-02 2017-10-09  Standard Class
# 8153    8154  CA-2018-140151 2018-03-23 2018-03-25     First Class
# 2623    2624  CA-2018-127180 2018-10-22 2018-10-24     First Class
# 4190    4191  CA-2018-166709 2018-11-17 2018-11-22  Standard Class
# 9039    9040  CA-2017-117121 2017-12-17 2017-12-21  Standard Class
# 4098    4099  CA-2015-116904 2015-09-23 2015-09-28  Standard Class
# 4277    4278  US-2017-107440 2017-04-16 2017-04-20  Standard Class
# 8488    8489  CA-2017-158841 2017-02-02 2017-02-04    Second Class
# 6425    6426  CA-2017-143714 2017-05-23 2017-05-27  Standard Class
#
#      Customer ID       Customer Name      Segment        Country  \
# 2697    SM-20320         Sean Miller  Home Office  United States
# 6826    TC-20980        Tamara Chand    Corporate  United States
# ...

# %%
# How many of the top 10 are Technology?
high.loc[high["Category"]=="Technology"].shape[0]
# Out:
# 8

# %%
#How many are Furniture?
high.loc[high["Category"] == "Furniture"].shape[0]
# Out:
# 0

# %%
#How many are Office Supplies?
high.loc[high["Category"]== "Office Supplies"].shape[0]
# Out:
# 2

# %%
#in sub catagry how many are the Machines
high.loc[high["Sub-Category"]== "Machines"].shape[0]
# Out:
# 3

# %%
#in sub catagry how many are the Copiers
high.loc[high["Sub-Category"]== "Copiers"].shape[0]
# Out:
# 5

# %%
#in sub catagry how many are the Binders
high.loc[high["Sub-Category"]== "Binders"].shape[0]
# Out:
# 2

# %%
#How much total Sales does each Category generate?
cat_sales = df.groupby("Category")["Sales"].sum()
cat_sales
# Out:
# Category
# Furniture          728658.5757
# Office Supplies    705422.3340
# Technology         827455.8730
# Name: Sales, dtype: float64

# %%
#Calculate the percentage contribution of each category to total sales.
total_sales = df["Sales"].sum()
cat_pers = (cat_sales/total_sales)*100
cat_pers
# Out:
# Category
# Furniture          32.219621
# Office Supplies    31.192167
# Technology         36.588212
# Name: Sales, dtype: float64
